# %% [markdown]
# # Module 1 - Lesson 1: The Way of the Programming

# %% [markdown]
# ## Introduction
#
# The goal of this coursepack is to teach you to understand and create computer programs
# in Python. At the beginning of each chapter, we will outline for you the learning goals and
# objectives that should be accomplished once you have gone through the chapter.
# Writing computer programs requires not only mechanistic thinking but creative problem
# solving. Problem solving means the ability to formulate problems, think creatively about
# solutions, and express a solution clearly and accurately. As it turns out, the process of
# learning to program is an excellent opportunity to practice problem solving skills.

# %% [markdown]
# ## Activity
#
# 1. *Why	do	you	think	uderstanding	computer	programs	is	relevant	in	our	time	today especially	in	the	new	normal?*
#
#     - Understanding how computer programs works is now a necessary skill to have now that we are having a new normal life due to the pandemic. We all know that most of the workers all around the world are now relying on the Internet to work at home so it is good for us to properly manifest and use the full potential our computers has for us to use. Moreover, as time passes by, our technology are advancing to a new level as new programs are invented and more oppurtunities will open as computer programming will become more advanced, so it is a great advantage for us to learn and understand computer programming.
#
#
# 2. *If	you	were	able	to	learn	computer	program	what	program	will	you code?	Why?*
#
#     - Nowadays, there's an abundant amount of business companies that are booming up using the Internet platforms, such as Shopee and Lazada, so I think the best and convenient computer program to learn would be PHP, Java and CSS. I chose these computer programs because business companies online needed a lot of databases for their data, files, and stocks and these computer programs can make it for them. Moreover, in regards for their employees, by using these programs I can create a website and/or an application that can conveniently monitor them. Lastly, for the system inside the business companies, by the help of these computer programs, I can easily innovate and automate the system making it easier for the business owners to check and supervise his whole business.
#
#
# 3. *What	would	be	your	primary	motivation	in	learning	programming?*
#
#     - Keeping in mind that the technology that we have is gradually advancing and improving, my primary motivation is to make use of its full potential to create something convenient that can help the humanity to live easily in the near future. Learning computer programming can really be an essential skill to have since we are now living in an era where technology matters and by learning computer programming I can become a successful Electronics and Communication Engineer in the near future.

# %% [markdown]
# ## The Python Programming Language

# %% [markdown]
# Python is one of the High-Level languages. High-Level languages has its own disadvantage like it takes time to process the code before it can run it but high-level languages have also many advantages. First, it is easier to write codes in high-level languages. Second, it is more portable, you can open it on any pc.

# %% [markdown]
# ### More About Programs
#
# A program is a sequence of instructions that specifies how to perform a computation. <!-- spaces -->
#
# 1. **_input_** -
# Get data from the keyboard, a file, or some other device.
# 2. **_output_** -
# Display data on the screen or send data to a file or other device.
# 3. **_math and logic_** -
# Perform basic mathematical operations like addition and multiplication and logical
# operations like and, or, and not.
# 4. **_conditional execution_** -
# Check for certain conditions and execute the appropriate sequence of statements.
# 5. **_repetition_** -
# Perform some action repeatedly, usually with some variation

# %% [markdown]
# ### Review of Control Structures

# %% [markdown]
# For Loop Example:

# %%
for character in "ELECTRONICS":
 print(character)
# Out:
# E
# L
# E
# C
# T
# R
# O
# N
# I
# C
# S

# %% [markdown]
# While Loop Example:

# %%
grocery_item = ""
while grocery_item != "done":
 grocery_item = input("Please write down an item to add to your grocery list. When you are done writing the list simply type: done")
 print(grocery_item)
# Out:
# Please write down an item to add to your grocery list. When you are done writing the list simply type: donemilk
# milk
# Please write down an item to add to your grocery list. When you are done writing the list simply type: donerice
# rice
# Please write down an item to add to your grocery list. When you are done writing the list simply type: donecookies
# cookies
# Please write down an item to add to your grocery list. When you are done writing the list simply type: donetoothpaste
# toothpaste
# Please write down an item to add to your grocery list. When you are done writing the list simply type: donedone
# done

# %% [markdown]
# Conditionals Example:

# %%
grocery_item = ""
grocery_list = []
while grocery_item != "done":
    grocery_item = input("Please write down an item to add to your grocery list. When you are done writing the list then simply type: done")
    if grocery_item == 'done':
        continue
    else:
        print("adding the item to the list")
        grocery_list.append(grocery_item)
print("Here is our grocery list:")
print(grocery_list)
# Out:
# Please write down an item to add to your grocery list. When you are done writing the list then simply type: donecoffee
# adding the item to the list
# Please write down an item to add to your grocery list. When you are done writing the list then simply type: donerice
# adding the item to the list
# Please write down an item to add to your grocery list. When you are done writing the list then simply type: donesugar
# adding the item to the list
# Please write down an item to add to your grocery list. When you are done writing the list then simply type: donesalt
# adding the item to the list
# Please write down an item to add to your grocery list. When you are done writing the list then simply type: donedone
# Here is our grocery list:
# ['coffee', 'rice', 'sugar', 'salt']

# %% [markdown]
# ### Formal and Natural Languages
#
# * **_Formal Languages_** - languages that has specific applications
# * **_Natural Languages_** - Language that humans speak

# %% [markdown]
# ### Typical First Program

# %%
print("Hello, World!") #This is the most basic command
# Out:
# Hello, World!

# %% [markdown]
# ### Comments
#
# * text that is intended only for the human reader - it is completely ignored by the interpreter

# %%
#---------------------------------------------------
# This demo program shows off how elegant Python is!
# Written by Joe Soap, December 2010.
# Anyone may freely copy or modify this program.
#---------------------------------------------------
print("Hello, World!") # Isn't this easy!
# Out:
# Hello, World!

# %% [markdown]
# ## *APPLICATIONS*:

# %% [markdown]
# 1. *Why do you think Python is the most applicable programming language for scientific computing?*
#
#     - From all the programming languages that I learned so far, from Java, C#, C++, and Python, I can really say that the Python language is easier to understand and I think I can easily understand it since it uses the basics from other programming languages such as C# and C++. Lastly, it is the best language to use for scientific computing since the Python language already has a tool to easily help for scientific computing.
#
# 2. *If	Python	can	build	anything,	where	do	you	think	Python	is	not	applicable	for?*
#
#     - I think the Python programming laguage has its limits on its slow processing speed and its ability to consume massive memory space, so I think that it is not applicable to use for developing any games such as mobile games and/or desktop games.

# %% [markdown]
# ### Exercise 1: Mailing Address (Solved, 9 Lines)
#
# Create a program that displays your name and complete mailing address. The address should be printed in the format that is normally used in the area where you live. Your program does not need to read any input from the user.

# %%
print("Complete Name: Eduardo Branzuela Calaque Jr.")
print("Complete Address: Purok 9, Juario Village, Matina, Davao City, Philippines")
print("Course: Bachelor Science in Electronics and Communication Engineering - BSEcE")
print("School: University of Southeastern Philippines")
# Out:
# Complete Name: Eduardo Branzuela Calaque Jr.
# Complete Address: Purok 9, Juario Village, Matina, Davao City, Philippines
# Course: Bachelor Science in Electronics and Communication Engineering - BSEcE
# School: University of Southeastern Philippines

# %% [markdown]
# ## Exercise 2: Area of Room (solved, 13 Lines)
#
# Write a program that asks the user to enter the width and length of a room. Once these values have been read, your program should compute and display the area of the room. The length and the width will be entered as floating-point numbers. Include
# units in your prompt and output message; either feet or meters, depending on which unit you are more comfortable working with

# %%
#Compute the Area of the room
length = float(input("Enter the desired length of the room in ft/feet: "))
width = float(input("Enter the desired width of the room in ft/feet: "))

area = length * width

print("The area of the room is",area, "square-feet.")
# Out:
# Enter the desired length of the room in ft/feet: 10
# Enter the desired width of the room in ft/feet: 10
# The area of the room is 100.0 square-feet.

# %% [markdown]
# ## Exercise 3: Arithmetic (solve, 22 lines)
#
# Create a program that reads two integers, a and b, from the user. Your program should
# compute and display:
#
#     •The sum of a and b
#     •The difference when b is subtracted from a
#     •The product of a and b
#     •The quotient when a is divided by b
#     •The remainder when a is divided by b
#     •The result of log10 a
#     •The result of log ab

# %%
#The sum of a and b
print("Enter two integers you want to add")

a = float(input("Enter any integer: "))
b = float(input("Enter any integer: "))

sum = a + b

print("The sum of the two integers is", sum)
# Out:
# Enter two integers you want to add
# Enter any integer: 100
# Enter any integer: 200
# The sum of the two integers is 300.0

# %%
#The difference when b is subtracted from a
print("Enter two integers you want to subtract")

b = float(input("Enter any integer value for b: "))
a = float(input("Enter any integer value for a: "))

difference = b - a

print("The difference of b - a is", difference)
# Out:
# Enter two integers you want to subtract
# Enter any integer value for b: 10
# Enter any integer value for a: 2
# The difference of b - a is 8.0

# %%
#The product of a and b
print("Enter two integers you want to multiply")

a = float(input("Enter any integer: "))
b = float(input("Enter any integer: "))

product = a * b

print("The product of the two integers is", product)
# Out:
# Enter two integers you want to multiply
# Enter any integer: 10
# Enter any integer: 21
# The product of the two integers is 210.0

# %%
#The quotient when a is divided by b
print("Enter two integers you want to divide")

a = float(input("Enter any integer value for a: "))
b = float(input("Enter any integer value for b: "))

quotient = a/b

print("The quotient of a/b is", quotient)
# Out:
# Enter two integers you want to divide
# Enter any integer value for a: 10
# Enter any integer value for b: 3
# The quotient of a/b is 3.3333333333333335

# %%
#The remainder when a is divided by b
print("Enter two integers you want to divide and the remainder will be shown to you")

a = float(input("Enter your Dividend: "))
b = float(input("Enter your Divisor: "))

remainder = a % b

print("The remainder of the quotient is", remainder)
# Out:
# Enter two integers you want to divide and the remainder will be shown to you
# Enter your Dividend: 10
# Enter your Divisor: 4
# The remainder of the quotient is 2.0

# %%
#The result of log10 a
print("Enter any integer that you want to solve for its logarithm")

a = float(input("Enter any integer for a: "))

import math

math.log10( a )

print("math.log10(a) is", math.log10(a))
# Out:
# Enter any integer that you want to solve for its logarithm
# Enter any integer for a: 15
# math.log10(a) is 1.1760912590556813

# %%
#The result of log ab
print("Enter any integer for a and b")

a = float(input("integer a: "))
b = float(input("integer b: "))

import math
math.log10(a*b)

print("math.log10(a*b) is", math.log10(a*b))
# Out:
# Enter any integer for a and b
# integer a: 20
# integer b: 10
# math.log10(a*b) is 2.3010299956639813

# %% [markdown]
# ## Exercise 4: Area and Volume (15 lines)
#
# Write a program that begins by reading a radius, r, from the user. The program will continue by computing and displaying the area of a circle with radius r and the volume of a sphere with radius r. Use the pi constant in the math module in your
# calculations.

# %%
print("Enter any radius")

import math
r = float(input("Enter any radius for r in meters: "))

area = math.pi * r * r 
volume = (4/3) * math.pi * r * r * r

print("The area of a circle with radius r is",area,"meter-squared")
print("The volume of a sphere with a radius r is", volume,"cubic meter")
# Out:
# Enter any radius
# Enter any radius for r in meters: 40
# The area of a circle with radius r is 5026.548245743669 meter-squared
# The volume of a sphere with a radius r is 268082.573106329 cubic meter
